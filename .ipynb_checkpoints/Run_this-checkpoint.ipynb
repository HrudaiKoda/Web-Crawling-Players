# %%
#Run any one cell to select a certain url

# %%
import getpass
import os

password = getpass.getpass()
command = "sudo -S apt-get install chromium-chromedriver"
os.system('echo %s | %s' % (password, command))
command = "sudo -S apt-get update"
os.system('echo %s | %s' % (password, command))
command = "sudo -S apt-get install chromium-chromedriver"
os.system('echo %s | %s' % (password, command))

# If facing issues with the default firefox driver for webscraping using selenium , run the below code
# !sudo apt-get install chromium-chromedriver
# !sudo apt-get update
# !sudo apt-get install chromium-chromedriver
# !pip install selenium
# Here the chrome driver is being used , hence replace firefox with Chrome driver as given below
# !pip install webdriver-manager

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
wd = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# Out:
# ········
# Requirement already satisfied: selenium in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from selenium) (1.24.3)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: webdriver-manager in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (3.4.2)
# Requirement already satisfied: crayons in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: configparser in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from webdriver-manager) (5.0.2)
# Requirement already satisfied: requests in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from webdriver-manager) (2.21.0)
# Requirement already satisfied: colorama in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from crayons->webdriver-manager) (0.4.3)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from requests->webdriver-manager) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from requests->webdriver-manager) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from requests->webdriver-manager) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/lib/python3.7/site-packages (from requests->webdriver-manager) (3.0.4)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/gokulvamsit/sem4-summer/IndicWiki/Gokul_IndicWiki/bin/python -m pip install --upgrade pip' command.
# ====== WebDriver manager ======
# Current google-chrome version is 89.0.4389
# Get LATEST driver version for 89.0.4389
# Driver [/home/gokulvamsit/.wdm/drivers/chromedriver/linux64/89.0.4389.23/chromedriver] found in cache

# %%
#Alphabetical parse url
#url = "https://www.espncricinfo.com/ci/content/player/country.html?country=6;alpha=A"

# %%
from bs4 import BeautifulSoup as bf
import requests
import pandas as pd
import time
from selenium import webdriver

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# driver = webdriver.Firefox()
# driver = webdriver.Chrome(options=options)
driver = wd

# %%
def evaluate(html):
  select_divs = html.find_all('div',class_="card overflow-hidden mb-3")
  exist = 0
  location = 0
  for i in range(len(select_divs)):
    check = ""
    try:
      check = select_divs[i].find('p',class_="benton-bold pl-3 pt-4 pb-3 m-0 player-card-header").text
    except:
      k = 1
    if(check == "Career Averages"):
      exist = 1
      location = i
      break
  return exist,select_divs[location]

# %%
# Handling images
def get_player_image(player_url):
    # For fixing installation errors on linux: `sudo apt install firefox-geckodriver`
    global driver
    driver.get(player_url)
    time.sleep(2)
    images = driver.find_elements_by_tag_name('img')
    images = [image for image in images if "player-card__face" in image.get_attribute("class")]
    if len(images) < 1:
        return ["image"], [""]
    print(images[0].get_attribute("src"))
    return ["image"], [images[0].get_attribute("src")]

# %%
# Get trophy info
def get_major_trophies_information(major_trophies_soup):
    major_trophies_results = {}
    all_h5_tags = major_trophies_soup.find_all('h5', class_="border-bottom-gray-300 m-0 pl-3 pb-2 table-header")
    if all_h5_tags is None:
        return None
    required_h5_tag = all_h5_tags[0]
    for h5_tag in all_h5_tags:
        if str(h5_tag.text).strip() == "In Major Trophies":
            required_h5_tag = h5_tag
            break
    if str(required_h5_tag.text).strip() != "In Major Trophies":
        return ["Major trophies"], [[major_trophies_results]]
    major_trophies_table_head = required_h5_tag.findNext('thead')
    major_trophies_table_headings = major_trophies_table_head.find_all('th')
    major_trophies_table_headings_count = 0
    major_trophies_headings_list = []
    for table_heading in major_trophies_table_headings:
        major_trophies_headings_list.append(table_heading.text)
    major_trophies_table_headings_count = len(major_trophies_headings_list)
    # print('Major Trophies table Head count', major_trophies_table_headings_count)
    current_title = "HOME"
    major_trophies_table_body = major_trophies_table_head.findNext('tbody')
    major_trophies_table_data = major_trophies_table_body.find_all('td')
    t = 0
    for table_data in major_trophies_table_data:
        attribute_number = t % major_trophies_table_headings_count
        if(attribute_number != 0):
            major_trophies_results[current_title][major_trophies_headings_list[attribute_number]] = table_data.text
        else:
            current_title = table_data.text
            major_trophies_results[current_title] = {}
        t += 1
    print(major_trophies_results)
    return ["Major trophies"], [[major_trophies_results]]

# %%
# Statistical analysis - Home, Away stats and function call to trophy info
def get_statistical_analysis_and_trophy_info(req):
    analysis_labels = []
    analysis_results = []
    analysis_url = req.url + "/bowling-batting-stats"
    #analysis_url = "https://www.espncricinfo.com/player/virat-kohli-253802/bowling-batting-stats"
    
    # selecting dropdown option
    global driver
    driver.get(analysis_url)
    # loading page
    time.sleep(2)
    dropdowns = driver.find_elements_by_class_name('dropdown-container')
    for dropdown in dropdowns:
        is_format_dropdown = str(dropdown.find_elements_by_tag_name('button')[0].text).strip() in ["Test", "ODI", "T20I", "Test+ODI+T20I"]
        is_role_dropdown = str(dropdown.find_elements_by_tag_name('button')[0].text).strip() in ["Batting", "Bowling", "Fielding", "Allround"]
        if (not is_format_dropdown) and (not is_role_dropdown):
            continue
        required_span_text = "Test+ODI+T20I"
        if is_role_dropdown:
            required_span_text = "Allround"
        dropdown.find_elements_by_tag_name('button')[0].click()
        all_list_items = dropdown.find_elements_by_tag_name('li')
        for list_item in all_list_items:
            span_text = list_item.find_elements_by_tag_name('span')[0].text
            if span_text == required_span_text:
                list_item.click()
                break
    # waiting for changes to load
    time.sleep(2)
    analysis_page = driver.page_source
    analysis_soup = bf(analysis_page, "html.parser")
    
    all_h5_tags = analysis_soup.find_all('h5', class_="border-bottom-gray-300 m-0 pl-3 pb-2 table-header")
    if all_h5_tags is None:
        return None
    required_h5_tag = all_h5_tags[0]
    for h5_tag in all_h5_tags:
        if str(h5_tag.text).strip() == "Home vs Away":
            required_h5_tag = h5_tag
            break
    if str(required_h5_tag.text).strip() != "Home vs Away":
        return get_major_trophies_information(analysis_soup)
    analysis_table_head = required_h5_tag.findNext('thead')
    analysis_table_headings = analysis_table_head.find_all('th')
    analysis_table_headings_count = 0
    analysis_table_headings_list = []
    for table_heading in analysis_table_headings:
        analysis_table_headings_list.append(table_heading.text)
    analysis_table_headings_count = len(analysis_table_headings_list)
    # print('Analysis table Head count', analysis_table_headings_count)
    current_title = "HOME"
    analysis_table_body = analysis_table_head.findNext('tbody')
    analysis_table_data = analysis_table_body.find_all('td')
    t = 0
    for table_data in analysis_table_data:
        attribute_number = t % analysis_table_headings_count
        if(attribute_number != 0):
            analysis_results.append(table_data.text)
            analysis_labels.append(current_title + "_" + analysis_table_headings_list[attribute_number])
        else:
            current_title = table_data.text.upper()
        t += 1
    # for i in range(len(analysis_labels)):
    #     print(f'{analysis_labels[i]} : {analysis_results[i]}')
    trophy_label, trophy_result = get_major_trophies_information(analysis_soup)
    return analysis_labels + trophy_label, analysis_results + trophy_result

# %%
def find_relations(Relations):
    relations_container = Relations.find_next('div')
    individual_relations = relations_container.find_all('span')
    total_relations = list()
    for i in range(len(individual_relations)):
        name = individual_relations[i].find('h5').text
        bond = individual_relations[i].find('p').text
        total_relations.append([name,bond])
    return total_relations

# %%
#Get relevant information related to a player using each player's url
def load(req,final_list_players,ind,u,debut_url):
    lab = list()
    result = list()
    soup = bf(req.text,"html.parser")
    print(soup.title)
    search_tag_container = soup.find_all('h5',class_='player-card-description gray-900')
    count = 0
    for job_elem in search_tag_container:
        result.append(job_elem.text)
        count+=1
    search_tag_container = soup.find_all('p',class_="text-uppercase gray-700 mb-0 pb-0-5 player-card-heading")
    for job_elem in search_tag_container:
        lab.append(job_elem.text)
    ##################################
    Relations = soup.find('p',class_="text-uppercase gray-700 mb-0 player-card-heading text-uppercase")
    #relation_players = soup.find('p',class_="player-card-description player-description-link gray-900 m-0 player-link")
    if(Relations != None):
        if(Relations.text.lower()=='relations' or Relations.text.lower()=='relation'):
            lab.append("Relations")
            all_relations = find_relations(Relations)
            result.append([all_relations])
    ######################################
    rec = extra(u)
    lab.append("Records")
    result.append([rec])
    print(result)
    ##########################################
    records_format , records_data = format_records(u)
    for iter in range(len(records_format)):
      lab.append(records_format[iter])
      result.append([records_data[iter]])
    ###########################################
    matches = debut(debut_url)
    result.append([matches])
    lab.append("Matches")
    ##########################################
    lab.append("Teams")
    team_data = teams_data(soup)
    result.append([team_data])
    ###########################################
    analysis_and_trophy_labels, analysis_and_trophy_results = get_statistical_analysis_and_trophy_info(req)
    lab = lab + analysis_and_trophy_labels
    result = result + analysis_and_trophy_results
    ###########################################
    player_image_label, player_image_result = get_player_image(req.url)
    lab = lab + player_image_label
    result = result + player_image_result
    ###########################################
    career_span_tag = soup.find('div', class_="intl_career-desktop")
    career_span_tag_text = career_span_tag.findNext('p').text
    if len(career_span_tag_text) > 0:
        career_span_info = ""
        start_index = 0
        for i in range(len(career_span_tag_text)):
            if career_span_tag_text[i] == '1' or career_span_tag_text[i] == '2':
                start_index = i
                break
        career_span_tag_text = career_span_tag_text[start_index:]
        result.append(career_span_tag_text)
        lab.append("career_span")
    ###########################################
    search_tag_container = soup.find('div',class_="player-card__details")
    l = list()
    for job_elem in search_tag_container:
        l.append(job_elem.text)
        count+=1
    p = l[1].split("|")
    l.pop()
    l.pop()
    l = l+p
    result = result + l
    l_label = ["Player Name" , "Nationality ", "player-type"]
    lab = lab + l_label
    ##########################
    valid,soup = evaluate(soup)
    if(valid == 1):
        search_tag_container = soup.findAll('thead')
        for m in range(len(search_tag_container)):
            actual_heading = search_tag_container[m].findPrevious('h5').text
            current_string = "_"
            if "Bowling" in actual_heading:
                current_string = "Bowling_"
            elif "Batting" in actual_heading:
                current_string = "Batting_"
            else:
                continue
            tag_content = search_tag_container[m].find_all('th')
            head = 0
            table_labels = list()
            table_labels_1 =list()
            for job_elem in tag_content:
                table_labels.append(job_elem.text)
                head+=1
            print('Head count',head)

            tag_content = search_tag_container[m].findNext('tbody').find_all('td')
            track_head_label = 0
            current_format = ""
            for job_elem in tag_content:
                attribute_number = track_head_label % head
                if(attribute_number != 0):
                    result.append(job_elem.text)
                    lab.append(current_string + current_format + '_' + table_labels[attribute_number])
                    count += 1
                else:
                    current_format = job_elem.text
                track_head_label += 1
    ####################################
      
    print('label--',len(lab))
    print('result--',len(result))
    
    lo = dict(zip(lab,result))
    lp = pd.DataFrame(lo,index=[ind])
    final_list_players.append(lp)
    print('count',count)

# %%
#Get individual player's "Records" information.
import re
def extra(l):
    re = requests.get(l)
    time.sleep(2)
    so = bf(re.text,"html.parser")
    res1 = so.find_all('div',class_='col-14 d-flex flex-row')
    res = so.find_all('div',class_='row bg-gray-100 class-record-row-p d-flex align-items-center')
    #print(res1)
    url_list = list()
    for i in range(len(res1)):

        pre = res1[i].find_all('h1')
        loi = res1[i].find_all('p',class_='record-class-title m-0')
        #print(loi)    
        for j in range(len(pre)):
            #print(pre[j].text)
            #print(loi[j].text)
            url_list.append(str(pre[j].text)  +str(" ") + str(loi[j].text))
    return url_list

# %%
def format_records(url):
  req = requests.get(url)
  soup = bf(req.text,"html.parser")
  record_sections = soup.find_all('div',class_="card content-block")
  required = ['Test Records','ODI Records','T20I Records']
  available_labels = list()
  labels_data = list()
  count = -1
  for i in range(len(record_sections)):
    name = record_sections[i].find('h5',class_="m-0")
    if(name.text in required):
      available_labels.append(name.text)
      labels_data.append([])
      count +=1
      individual_block_record = record_sections[i].find_all('a',class_="gray-900 benton-normal d-block")
      for i in range(len(individual_block_record)):
        try:
          a = individual_block_record[i].find('span',class_="m-0 benton-bold gray-1000 pr-3").text
          b = individual_block_record[i].find('span',class_="list-record-title").text
          c = individual_block_record[i].find('span',class_="m-0 ml-1 gray-600").text
          labels_data[count].append(str(a)+str(" ")+str(b)+str(" ")+str(c))
        except:
          no = 1
  return available_labels , labels_data

# %%
def teams_data(so):
  teams = []
  loi = so.find_all('h5',class_='m-0 ml-2 link-border-bottom player-description-link')
  for i in range(len(loi)):
    teams.append(loi[i].text)
  return teams

# %%
def debut(link):
  player_match = list()
  url = link
  request = requests.get(url)
  soup = bf(request.text,"html.parser")
  search_tag_container = soup.find_all('div',{'id':'debut-last-matches'})
  cp_jo = search_tag_container
  if(len(search_tag_container) != 0):
    total = cp_jo[0].find_all('div',class_="")
    for i in range(len(total)):
      p =total[i]
      a= p.find('h5',{'class':"benton-bold player-matches-subtitle d-flex justify-content-between align-items-center player_matches-dropdown m-0"})
      k = total[i].find_all('span',class_="match-event-row-debut-last white-space-nowrap")
      search_tag_container = total[i].find_all('span',{"class": "player-match-link"})
      new = total[i].find_all('div',{"class":"col-12 player-match-event-cell white-space-nowrap"})
      #print(a)
      #print(k[0])
      #print(new)
      try:
        l =a.span.decompose()
      except:
        player_match.append(a.text)
        #print(a.text)
      else:
        player_match.append(a.text)
        #print(a.text)
      for j in range(len(k)):
        try:
          temp = search_tag_container[j].text
        except:
          temp = new[j].text
        append = k[j].text + str(" ") + temp
        player_match.append(append)
        #print(k[j].text,end=" ")
        #print(search_tag_container[j].text)
  return player_match

# %%
import time
final_list_players = list()
tot_count = 0
for country_id in range(1,12):
  #Country based parse url
  url = "https://www.espncricinfo.com/ci/content/player/index.html?country="+str(country_id)
  req = requests.get(url)
  soup = bf(req.text,"html.parser")
  #Fetch total urls of players belonging to a country
  country_name = soup.find('span',{'id':'ciShowCountry'})
  print("-------------------------------------------------")
  print(country_name.text)
  print("-------------------------------------------------")
  search_tag_container = soup.find_all('td')
  u = list()
  for job_elem in search_tag_container:
      u.append(job_elem.find('a'))
      #result.append(job_elem.text)
  l = set(u)
  l = list(l)
  for i in range(len(l)):
      u = "https://www.espncricinfo.com"
      rl = l[i]["href"]
      link = u+rl
      print(link)
      #link = "https://www.espncricinfo.com/player/virat-kohli-253802"
      req = requests.get(link)
      time.sleep(2)
      print('player-',i,end=" ")
      ind = tot_count
      tot_count += 1
      record_url = req.url+str("/tests-odi-t20-records")
      debut_url = req.url+str("/matches")
      #debut(debut_url)
      load(req,final_list_players,ind,record_url,debut_url)
      #print(record_url)
      #jk = extra(record_url)
      #print(jk)
  #driver.close()
# Out:
# -------------------------------------------------
# New Zealand
# -------------------------------------------------
# https://www.espncricinfo.com/ci/content/player/213674.html
# player- 0 <title>Todd Astle profile and biography, stats, records, averages, photos and videos</title>
# ['Todd Duncan Astle', 'September 24, 1986, Palmerston North, New Zealand', '34y 247d', 'Right hand bat', 'Legbreak', 'Bowler', [[['AM Astle', ' (father)']]], [['6th Best strike rate in an innings (3.0)']]]
# {'ICC World Test Champ': {'Span': '2020-2020', 'Mat': '1', 'Inns': '2', 'Overs': '40.0', 'Mdns': '1', 'Runs': '152', 'Wkts': '3', 'BBI': '2/111', 'BBM': '3/152', 'Avg': '50.66', 'Econ': '3.80', 'SR': '80.00', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2020-2020', 'Mat': '1', 'Inns': '2', 'Overs': '40.0', 'Mdns': '1', 'Runs': '152', 'Wkts': '3', 'BBI': '2/111', 'BBM': '3/152', 'Avg': '50.66', 'Econ': '3.80', 'SR': '80.00', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321314.png
# Head count 14
# Head count 15
# label-- 207
# result-- 207
# count 171
# https://www.espncricinfo.com/ci/content/player/38607.html
# player- 1 <title>William Somerville profile and biography, stats, records, averages, photos and videos</title>
# ['William Edgar Richard Somerville', 'August 09, 1984, Wadestown, Wellington', '36y 293d', 'Right hand bat', 'Right arm offbreak', 'Bowler', [[]]]
# {'ICC World Test Champ': {'Span': '2019-2020', 'Mat': '3', 'Inns': '6', 'Overs': '119.2', 'Mdns': '20', 'Runs': '360', 'Wkts': '8', 'BBI': '3/83', 'BBM': '4/156', 'Avg': '45.00', 'Econ': '3.01', 'SR': '89.50', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2020-2020', 'Mat': '1', 'Inns': '2', 'Overs': '39.0', 'Mdns': '2', 'Runs': '135', 'Wkts': '1', 'BBI': '1/99', 'BBM': '1/135', 'Avg': '135.00', 'Econ': '3.46', 'SR': '234.00', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321321.png
# Head count 14
# Head count 15
# label-- 151
# result-- 151
# count 117
# https://www.espncricinfo.com/ci/content/player/547766.html
# player- 2 <title>Jacob Duffy profile and biography, stats, records, averages, photos and videos</title>
# ['Jacob Andrew Duffy', 'August 02, 1994, Lumsden, Southland', '26y 300d', 'Right hand bat', 'Right arm fast medium', 'Bowler', [['4th Best figures in a innings on debut (4)']]]
# {'overview': {'Mat': '1', 'Inns': '1', 'Overs': '4.0', 'Mdns': '0', 'Runs': '33', 'Wkts': '4', 'BBI': '4/33', 'Avg': '8.25', 'Econ': '8.25', 'SR': '6.00', '4w': '1', '5w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_s_100/lsci/db/PICTURES/CMS/313900/313998.jpg
# Head count 14
# Head count 15
# label-- 136
# result-- 136
# count 117
# https://www.espncricinfo.com/ci/content/player/388802.html
# player- 3 <title>Tom Latham profile and biography, stats, records, averages, photos and videos</title>
# ['Thomas William Maxwell Latham', 'April 02, 1992, Christchurch, Canterbury', '29y 57d', 'Left hand bat', 'Right arm medium', 'Wicketkeeper', 'Wicketkeeper batter', [[['RT Latham', ' (father)']]], [[' Carrying bat through a completed innings (264*)', '4th Most dismissals in a series (21)', '3rd Most catches in a series (21)', ' Carrying bat through a completed innings (79*)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '11', 'Inns': '18', 'NO': '1', 'Runs': '680', 'HS': '154', 'Avg': '40.00', 'BF': '1456', 'SR': '46.70', '100s': '1', '50s': '5', '0s': '1', '4s': '71', '6s': '2'}, 'Trans-Tasman Trophy': {'Span': '2015-2020', 'Mat': '8', 'Inns': '16', 'NO': '0', 'Runs': '425', 'HS': '63', 'Avg': '26.56', 'BF': '1093', 'SR': '38.88', '100s': '0', '50s': '3', '0s': '1', '4s': '43', '6s': '1'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316600/316672.png
# Head count 15
# Head count 14
# label-- 224
# result-- 224
# count 172
# https://www.espncricinfo.com/ci/content/player/37737.html
# player- 4 <title>Brendon McCullum profile and biography, stats, records, averages, photos and videos</title>
# ['Brendon Barrie McCullum', 'September 27, 1981, Dunedin, Otago', '39y 244d', 'Right hand bat', 'Right arm medium, Right arm offbreak', 'Wicketkeeper', 'Wicketkeeper batter', [[['SJ McCullum', ' (father),'], ['NL McCullum', ' (brother)']]], [['5th Most consecutive matches for a team (101)', '8th Most dismissals in a match (9)', '4th Most runs in an innings (by batting position) (302)', '2nd Most double hundreds in a series (2)', '1st Most sixes in career (107)', '9th Longest individual innings (by minutes) (775)', ' 2000 runs and 100 wicketkeeping dismissals ', '3rd Highest partnership for the sixth wicket (352)', '6th Most dismissals in career (242)', '7th Most consecutive matches for a team (122)', '9th Most dismissals in a series (19)', '5th Most catches in career (227)', '5th Captains who have kept wicket and opened the batting (1)', '8th Most catches in a series (18)', '10th Highest maiden hundred (166)', '8th Most sixes in career (200)', ' 2000 runs and 100 wicketkeeping dismissals ', '1st Captains who have kept wicket and opened the batting (2)', '1st Most runs in an innings by a wicketkeeper (123)', '1st Fifties in consecutive innings (4)', '8th Most sixes in career (91)', '9th Highest percentage of runs in a completed innings (64.39)', '4th Fastest to 2000 runs (66)', '7th Highest partnership for the sixth wicket (85*)', '3rd Most consecutive matches for a team (208)', '10th Most dismissals in career (453)', '10th Most catches in career (419)', '4th Most sixes in career (398)']]]
# {'Trans-Tasman Trophy': {'Span': '2004-2016', 'Mat': '16', 'Inns': '30', 'NO': '1', 'Runs': '834', 'HS': '145', 'Avg': '28.75', 'BF': '1281', 'SR': '65.10', '100s': '2', '50s': '3', '0s': '2', '4s': '119', '6s': '16'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316500/316509.png
# Head count 15
# Head count 14
# label-- 224
# result-- 224
# count 172
# https://www.espncricinfo.com/ci/content/player/355269.html
# player- 5 <title>James Neesham profile and biography, stats, records, averages, photos and videos</title>
# ['James Douglas Sheahan Neesham', 'September 17, 1990, Auckland', '30y 254d', 'Jimmy Neesham', 'Left hand bat', 'Right arm medium fast', 'Batting allrounder', [['7th Most runs in an innings (by batting position) (137*)', ' Hundred on debut (137*)', '2nd Hundreds in consecutive matches from debut (2)', '2nd Highest strike rate in an innings (361.53)', '7th Worst career economy rate (6.06)']]]
# {'Trans-Tasman Trophy': {'Span': '2015-2015', 'Mat': '1', 'Inns': '2', 'NO': '0', 'Runs': '6', 'HS': '3', 'Avg': '3.00', 'BF': '40', 'SR': '15.00', '100s': '0', '50s': '0', '0s': '0', '4s': '0', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319781.png
# Head count 15
# Head count 14
# label-- 223
# result-- 223
# count 172
# https://www.espncricinfo.com/ci/content/player/277912.html
# player- 6 <title>Trent Boult profile and biography, stats, records, averages, photos and videos</title>
# ['Trent Alexander Boult', 'July 22, 1989, Rotorua', '31y 311d', 'Right hand bat', 'Left arm fast medium', 'Bowler', [[['JJ Boult', ' (brother)']]], [['7th Outstanding bowling analyses in an innings (7/34)', '10th Most four-wickets-in-an-innings in a career (13)', '3rd Fastest to 150 wickets (81)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '9', 'Inns': '18', 'Overs': '334.2', 'Mdns': '74', 'Runs': '996', 'Wkts': '34', 'BBI': '4/28', 'BBM': '6/117', 'Avg': '29.29', 'Econ': '2.97', 'SR': '59.00', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2011-2019', 'Mat': '7', 'Inns': '13', 'Overs': '261.0', 'Mdns': '35', 'Runs': '959', 'Wkts': '23', 'BBI': '5/60', 'BBM': '7/101', 'Avg': '41.69', 'Econ': '3.67', 'SR': '68.00', '5w': '1', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316600/316619.png
# Head count 14
# Head count 15
# label-- 223
# result-- 223
# count 171
# https://www.espncricinfo.com/ci/content/player/450860.html
# player- 7 <title>Adam Milne profile and biography, stats, records, averages, photos and videos</title>
# ['Adam Fraser Milne', 'April 13, 1992, Palmerston North', '29y 46d', 'Right hand bat', 'Right arm fast', 'Bowler', [['8th Best figures in a innings when on the losing side (4)', '1st Bowler/batters combinations (4)']]]
# {'World Cup': {'Span': '2015-2015', 'Mat': '6', 'Inns': '6', 'Overs': '39.2', 'Mdns': '1', 'Runs': '199', 'Wkts': '5', 'BBI': '2/56', 'Avg': '39.80', 'Econ': '5.05', 'SR': '47.20', '4w': '0', '5w': '0'}, 'Chappell-Hadlee': {'Span': '2015-2016', 'Mat': '4', 'Inns': '4', 'Overs': '26.4', 'Mdns': '0', 'Runs': '152', 'Wkts': '2', 'BBI': '1/42', 'Avg': '76.00', 'Econ': '5.70', 'SR': '80.00', '4w': '0', '5w': '0'}, 'ICC Champions Trophy': {'Span': '2017-2017', 'Mat': '3', 'Inns': '3', 'Overs': '21.2', 'Mdns': '0', 'Runs': '146', 'Wkts': '6', 'BBI': '3/79', 'Avg': '24.33', 'Econ': '6.84', 'SR': '21.30', '4w': '0', '5w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316600/316689.png
# Head count 14
# Head count 15
# label-- 190
# result-- 190
# count 144
# https://www.espncricinfo.com/ci/content/player/823509.html
# player- 8 <title>Glenn Phillips profile and biography, stats, records, averages, photos and videos</title>
# ['Glenn Dominic Phillips', 'December 06, 1996, East London, Eastern Cape, South Africa', '24y 174d', 'Right hand bat', 'Right arm offbreak', 'Wicketkeeper', 'Wicketkeeper batter', [[['DJ Grobbelaar', ' (brother-in-law),'], ['DN Phillips', ' (brother)']]], [['5th Most dismissals in an innings (4)', '3rd Most runs in an innings (by batting position) (108)']]]
# {'ICC World Test Champ': {'Mat': '1', 'Inns': '2', 'NO': '0', 'Runs': '52', 'HS': '52', 'Avg': '26.00', 'BF': '119', 'SR': '43.69', '100s': '0', '50s': '1', '0s': '1', '4s': '6', '6s': '1'}, 'Trans-Tasman Trophy': {'Mat': '1', 'Inns': '2', 'NO': '0', 'Runs': '52', 'HS': '52', 'Avg': '26.00', 'BF': '119', 'SR': '43.69', '100s': '0', '50s': '1', '0s': '1', '4s': '6', '6s': '1'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321223.png
# Head count 15
# Head count 14
# label-- 166
# result-- 166
# count 145
# https://www.espncricinfo.com/ci/content/player/381743.html
# player- 9 <title>Daryl Mitchell profile and biography, stats, records, averages, photos and videos</title>
# ['Daryl Joseph Mitchell', 'May 20, 1991, Hamilton', '30y 9d', 'Moose', 'Right hand bat', 'Right arm medium', 'Allrounder', [['1st Most catches by a substitute in an innings (3)']]]
# {'ICC World Test Champ': {'Span': '2020-2021', 'Mat': '3', 'Inns': '3', 'NO': '1', 'Runs': '153', 'HS': '102*', 'Avg': '76.50', 'BF': '217', 'SR': '70.50', '100s': '1', '50s': '0', '0s': '0', '4s': '14', '6s': '2'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321212.png
# Head count 15
# Head count 14
# label-- 195
# result-- 195
# count 172
# https://www.espncricinfo.com/ci/content/player/232364.html
# player- 10 <title>Tim Southee profile and biography, stats, records, averages, photos and videos</title>
# ['Timothy Grant Southee', 'December 11, 1988, Whangarei, Northland', '32y 169d', 'Right hand bat', 'Right arm medium fast', 'Bowler', [['9th Most runs in a career without a hundred (1690)', '8th Most sixes in an innings (9)', '7th Bowler/fielder combinations (73)', ' 1000 runs and 100 wickets ', ' 1000 runs, 50 wickets and 50 catches ', '6th Most runs in an innings (by batting position) (55)', '6th Outstanding bowling analyses in an innings (7/33)', '6th Most runs conceded in an innings (105)', '2nd Most wickets in career (99)', '3rd Most balls bowled in career (1782)', '1st Most runs conceded in career (2492)', '1st Most wickets taken caught by a wicketkeeper (15)', '6th Most catches in career (44)', '2nd Highest partnership for the tenth wicket (36)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '10', 'Inns': '20', 'Overs': '390.3', 'Mdns': '107', 'Runs': '1054', 'Wkts': '51', 'BBI': '5/32', 'BBM': '9/110', 'Avg': '20.66', 'Econ': '2.69', 'SR': '45.90', '5w': '3', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2008-2019', 'Mat': '13', 'Inns': '22', 'Overs': '456.2', 'Mdns': '83', 'Runs': '1540', 'Wkts': '37', 'BBI': '5/69', 'BBM': '9/162', 'Avg': '41.62', 'Econ': '3.37', 'SR': '74.00', '5w': '1', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316500/316596.png
# Head count 14
# Head count 15
# label-- 222
# result-- 222
# count 171
# https://www.espncricinfo.com/ci/content/player/277906.html
# player- 11 <title>Kane Williamson profile and biography, stats, records, averages, photos and videos</title>
# ['Kane Stuart Williamson', 'August 08, 1990, Tauranga', '30y 294d', 'Right hand bat', 'Right arm offbreak', 'Top order batter', [[['D Cleaver', ' (cousin)']]], [[' Hundred on debut (131)', ' 5000 runs and 50 fielding dismissals ', '2nd Highest partnership for the sixth wicket (365*)', '6th Youngest captains (21y 332d)', '3rd Most runs in an series by a captain (578)', '6th Most nineties in career (7)', '2nd Fifties in consecutive innings (6)', '3rd Fastest to 6000 runs (139)', ' 5000 runs and 50 fielding dismissals ', '5th Most matches as captain (49)', '2nd Highest percentage of runs in a completed innings (70.00)', '9th Fastest to 1000 runs (34)', '3rd Highest partnership for the fourth wicket (124)', '5th Most runs in a calendar year (2692)', '6th Most nineties in career (12)', '2nd Fifties in consecutive innings (7)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '9', 'Inns': '14', 'NO': '0', 'Runs': '817', 'HS': '251', 'Avg': '58.35', 'BF': '1432', 'SR': '57.05', '100s': '3', '50s': '1', '0s': '2', '4s': '100', '6s': '3'}, 'Trans-Tasman Trophy': {'Span': '2011-2019', 'Mat': '9', 'Inns': '18', 'NO': '1', 'Runs': '699', 'HS': '166', 'Avg': '41.11', 'BF': '1208', 'SR': '57.86', '100s': '2', '50s': '2', '0s': '2', '4s': '93', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316600/316618.png
# Head count 15
# Head count 14
# label-- 223
# result-- 223
# count 171
# https://www.espncricinfo.com/ci/content/player/539511.html
# player- 12 <title>Henry Nicholls profile and biography, stats, records, averages, photos and videos</title>
# ['Henry Michael Nicholls', 'November 15, 1991, Christchurch', '29y 195d', 'Left hand bat', 'Right arm offbreak', 'Top order batter', "St Andrew's College, Christchurch, New Zealand", [[]]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '10', 'Inns': '15', 'NO': '1', 'Runs': '585', 'HS': '174', 'Avg': '41.78', 'BF': '1168', 'SR': '50.08', '100s': '2', '50s': '1', '0s': '1', '4s': '59', '6s': '3'}, 'Trans-Tasman Trophy': {'Span': '2016-2019', 'Mat': '4', 'Inns': '8', 'NO': '0', 'Runs': '137', 'HS': '59', 'Avg': '17.12', 'BF': '294', 'SR': '46.59', '100s': '0', '50s': '1', '0s': '1', '4s': '12', '6s': '1'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319777.png
# Head count 15
# Head count 14
# label-- 222
# result-- 222
# count 172
# https://www.espncricinfo.com/ci/content/player/232359.html
# player- 13 <title>Colin Munro profile and biography, stats, records, averages, photos and videos</title>
# ['Colin Munro', 'March 11, 1987, Durban', '34y 79d', 'Left hand bat', 'Right arm medium fast', 'Opening batter', [['6th Most runs on a single ground (421)', '4th Highest career strike rate (156.44)', '3rd Fifties in consecutive innings (3)', '4th Most sixes in career (107)', '4th Highest partnership for the fourth wicket (123)']]]
# {'overview': {'Mat': '1', 'Inns': '2', 'NO': '0', 'Runs': '15', 'HS': '15', 'Avg': '7.50', 'BF': '26', 'SR': '57.69', '100s': '0', '50s': '0', '0s': '1', '4s': '3', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319772.png
# Head count 15
# Head count 14
# label-- 192
# result-- 192
# count 171
# https://www.espncricinfo.com/ci/content/player/625964.html
# player- 14 <title>Tim Seifert profile and biography, stats, records, averages, photos and videos</title>
# ['Tim Louis Seifert', 'December 14, 1994, Wanganui', '26y 166d', 'Right hand bat', 'Wicketkeeper', 'Wicketkeeper batter', [[]]]
# {'overview': {'Mat': '3', 'Inns': '2', 'NO': '0', 'Runs': '33', 'HS': '22', 'Avg': '16.50', 'BF': '27', 'SR': '122.22', '100s': '0', '50s': '0', '0s': '0', '4s': '2', '6s': '1'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321313.png
# Head count 15
# Head count 14
# label-- 164
# result-- 164
# count 144
# https://www.espncricinfo.com/ci/content/player/502714.html
# player- 15 <title>Mitchell Santner profile and biography, stats, records, averages, photos and videos</title>
# ['Mitchell Josef Santner', 'February 05, 1992, Hamilton', '29y 114d', 'Left hand bat', 'Slow left arm orthodox', 'Bowling allrounder', [[['EH Santner', ' (brother)']]], [['1st Outstanding bowling analyses in an innings (2/0)', '8th Most wickets taken stumped (8)']]]
# {'ICC World Test Champ': {'Span': '2019-2020', 'Mat': '4', 'Inns': '8', 'Overs': '118.3', 'Mdns': '13', 'Runs': '378', 'Wkts': '3', 'BBI': '2/52', 'BBM': '2/59', 'Avg': '126.00', 'Econ': '3.18', 'SR': '237.00', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2015-2019', 'Mat': '3', 'Inns': '6', 'Overs': '87.0', 'Mdns': '7', 'Runs': '312', 'Wkts': '3', 'BBI': '1/8', 'BBM': '2/62', 'Avg': '104.00', 'Econ': '3.58', 'SR': '174.00', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319792.png
# Head count 14
# Head count 15
# label-- 209
# result-- 209
# count 171
# https://www.espncricinfo.com/ci/content/player/379140.html
# player- 16 <title>Devon Conway profile and biography, stats, records, averages, photos and videos</title>
# ['Devon Philip Conway', 'July 08, 1991, Johannesburg, Transvaal', '29y 325d', 'Left hand bat', 'Right arm medium', 'Wicketkeeper batter', [['6th Most runs in an innings by a wicketkeeper (92*)', '1st Highest partnership for the third wicket (184)']]]
# {'overview': {'Mat': '3', 'Inns': '3', 'NO': '0', 'Runs': '225', 'HS': '126', 'Avg': '75.00', 'BF': '255', 'SR': '88.23', '100s': '1', '50s': '1', '0s': '0', '4s': '26', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321214.png
# Head count 15
# Head count 14
# label-- 165
# result-- 165
# count 144
# https://www.espncricinfo.com/ci/content/player/493773.html
# player- 17 <title>Lockie Ferguson profile and biography, stats, records, averages, photos and videos</title>
# ['Lachlan Hammond Ferguson', 'June 13, 1991, Auckland', '29y 350d', 'Lockie', 'Right hand bat', 'Right arm fast', 'Bowler', [[]]]
# {'ICC World Test Champ': {'Mat': '1', 'Inns': '1', 'Overs': '11.0', 'Mdns': '1', 'Runs': '47', 'Wkts': '0', 'Econ': '4.27', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Mat': '1', 'Inns': '1', 'Overs': '11.0', 'Mdns': '1', 'Runs': '47', 'Wkts': '0', 'Econ': '4.27', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321239.png
# Head count 14
# Head count 15
# label-- 189
# result-- 189
# count 172
# https://www.espncricinfo.com/ci/content/player/233713.html
# player- 18 <title>Neil Wagner profile and biography, stats, records, averages, photos and videos</title>
# ['Neil Wagner', 'March 13, 1986, Pretoria, Transvaal', '35y 77d', 'Left hand bat', 'Left arm medium fast', 'Bowler', [[]]]
# {'ICC World Test Champ': {'Span': '2019-2020', 'Mat': '7', 'Inns': '14', 'Overs': '282.3', 'Mdns': '62', 'Runs': '720', 'Wkts': '32', 'BBI': '4/66', 'BBM': '7/133', 'Avg': '22.50', 'Econ': '2.54', 'SR': '52.90', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2016-2020', 'Mat': '4', 'Inns': '8', 'Overs': '207.4', 'Mdns': '43', 'Runs': '553', 'Wkts': '24', 'BBI': '6/106', 'BBM': '7/133', 'Avg': '23.04', 'Econ': '2.66', 'SR': '51.90', '5w': '1', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321301.png
# Head count 14
# Head count 15
# label-- 166
# result-- 166
# count 117
# https://www.espncricinfo.com/ci/content/player/438563.html
# player- 19 <title>Mark Chapman profile and biography, stats, records, averages, photos and videos</title>
# ['Mark Sinclair Chapman', 'June 27, 1994, Hong Kong', '26y 336d', 'Left hand bat', 'Slow left arm orthodox', 'Allrounder', "King's College, Auckland", [[' Representing two countries ', ' Hundred on debut (124*)', ' Representing two countries ']]]
# {'WCL Championship': {'Span': '2015-2015', 'Mat': '2', 'Inns': '2', 'NO': '1', 'Runs': '151', 'HS': '124*', 'Avg': '151.00', 'BF': '151', 'SR': '100.00', '100s': '1', '50s': '0', '0s': '0', '4s': '11', '6s': '3'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321241.png
# Head count 15
# Head count 14
# label-- 181
# result-- 181
# count 145
# https://www.espncricinfo.com/ci/content/player/625960.html
# player- 20 <title>Kyle Jamieson profile and biography, stats, records, averages, photos and videos</title>
# ['Kyle Alex Jamieson', 'December 30, 1994, Auckland', '26y 150d', 'Right hand bat', 'Right arm fast medium', 'Bowler', [[]]]
# {'ICC World Test Champ': {'Span': '2020-2021', 'Mat': '6', 'Inns': '12', 'Overs': '200.2', 'Mdns': '70', 'Runs': '478', 'Wkts': '36', 'BBI': '6/48', 'BBM': '11/117', 'Avg': '13.27', 'Econ': '2.38', 'SR': '33.30', '5w': '4', '10w': '1'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321236.png
# Head count 14
# Head count 15
# label-- 193
# result-- 193
# count 171
# https://www.espncricinfo.com/ci/content/player/36581.html
# player- 21 <title>Neil Broom profile and biography, stats, records, averages, photos and videos</title>
# ['Neil Trevor Broom', 'November 20, 1983, Christchurch, Canterbury', '37y 190d', 'Right hand bat', 'Right arm medium', 'Middle order batter', [[['DJ Broom', ' (brother)']]], [['9th Highest partnership for the seventh wicket (123)']]]
# {'overview': {'Mat': '2', 'Inns': '3', 'NO': '0', 'Runs': '32', 'HS': '20', 'Avg': '10.66', 'BF': '72', 'SR': '44.44', '100s': '0', '50s': '0', '0s': '1', '4s': '5', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321300.png
# Head count 15
# Head count 14
# label-- 193
# result-- 193
# count 171
# https://www.espncricinfo.com/ci/content/player/55395.html
# player- 22 <title>Colin de Grandhomme profile and biography, stats, records, averages, photos and videos</title>
# ['Colin de Grandhomme', 'July 22, 1986, Harare', '34y 311d', 'Right hand bat', 'Right arm medium fast', 'Allrounder', [[['HL de Grandhomme', ' (great-uncle),'], ['LL de Grandhomme', ' (father)']]], [['1st Most catches in an innings (4)', '10th Highest partnership for the fourth wicket (109)']]]
# {'ICC World Test Champ': {'Span': '2019-2020', 'Mat': '6', 'Inns': '9', 'NO': '0', 'Runs': '300', 'HS': '83', 'Avg': '33.33', 'BF': '418', 'SR': '71.77', '100s': '0', '50s': '2', '0s': '0', '4s': '29', '6s': '7'}, 'Trans-Tasman Trophy': {'Span': '2019-2020', 'Mat': '3', 'Inns': '6', 'NO': '0', 'Runs': '148', 'HS': '52', 'Avg': '24.66', 'BF': '223', 'SR': '66.36', '100s': '0', '50s': '1', '0s': '0', '4s': '15', '6s': '2'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319771.png
# Head count 15
# Head count 14
# label-- 223
# result-- 223
# count 171
# https://www.espncricinfo.com/ci/content/player/497543.html
# player- 23 <title>Mark Craig profile and biography, stats, records, averages, photos and videos</title>
# ['Mark Donald Craig', 'March 23, 1987, Auckland', '34y 67d', 'Left hand bat', 'Right arm offbreak', 'Bowler', [['7th Worst career economy rate (3.80)']]]
# {'Trans-Tasman Trophy': {'Span': '2015-2016', 'Mat': '4', 'Inns': '7', 'Overs': '137.2', 'Mdns': '7', 'Runs': '666', 'Wkts': '10', 'BBI': '3/78', 'BBM': '3/204', 'Avg': '66.60', 'Econ': '4.84', 'SR': '82.40', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321242.png
# Head count 14
# Head count 15
# label-- 166
# result-- 166
# count 117
# https://www.espncricinfo.com/ci/content/player/959759.html
# player- 24 <title>Finn Allen profile and biography, stats, records, averages, photos and videos</title>
# ['Finnley Hugh Allen', 'April 22, 1999, Auckland', '22y 37d', 'Right hand bat', 'Occasional wicketkeeper', 'Top order batter', [[]]]
# {'overview': {'Mat': '3', 'Inns': '3', 'NO': '0', 'Runs': '88', 'HS': '71', 'Avg': '29.33', 'BF': '40', 'SR': '220.00', '100s': '0', '50s': '1', '0s': '1', '4s': '12', '6s': '4'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321220.png
# Head count 15
# Head count 14
# label-- 136
# result-- 136
# count 117
# https://www.espncricinfo.com/ci/content/player/854909.html
# player- 25 <title>Blair Tickner profile and biography, stats, records, averages, photos and videos</title>
# ['Blair Marshall Tickner', "October 13, 1993, Napier, Hawke's Bay", '27y 228d', 'Right hand bat', 'Right arm medium fast', 'Bowler', [[]]]
# {'overview': {'Span': '2019-2020', 'Mat': '6', 'Inns': '6', 'Overs': '22.0', 'Mdns': '0', 'Runs': '212', 'Wkts': '5', 'BBI': '2/25', 'Avg': '42.40', 'Econ': '9.63', 'SR': '26.40', '4w': '0', '5w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321206.png
# Head count 14
# Head count 15
# label-- 136
# result-- 136
# count 117
# https://www.espncricinfo.com/ci/content/player/38699.html
# player- 26 <title>Ross Taylor profile and biography, stats, records, averages, photos and videos</title>
# ['Luteru Ross Poutoa Lote Taylor', 'March 08, 1984, Lower Hutt, Wellington', '37y 82d', 'Right hand bat', 'Right arm offbreak', 'Middle order batter', [['5th Most runs in an innings (by batting position) (290)', ' Two unbeaten fifties in a match ', '3rd Most innings before first duck (58)', '6th Most fours in an innings (43)', ' 5000 runs and 50 fielding dismissals ', '2nd Most runs in an innings (by batting position) (181*)', '2nd Hundreds in consecutive innings (3)', '2nd Fifties in consecutive innings (6)', '6th Fastest to 8000 runs (203)', '2nd Most catches in an innings (4)', ' 5000 runs and 50 fielding dismissals ', '8th Highest partnership for the fifth wicket (195)', '4th Most matches in career (102)', '4th Most catches in career (46)', '10th Most sixes in career (270)', '3rd Most catches in career (340)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '11', 'Inns': '17', 'NO': '2', 'Runs': '469', 'HS': '86', 'Avg': '31.26', 'BF': '844', 'SR': '55.56', '100s': '0', '50s': '3', '0s': '0', '4s': '54', '6s': '2'}, 'Trans-Tasman Trophy': {'Span': '2008-2020', 'Mat': '12', 'Inns': '24', 'NO': '1', 'Runs': '999', 'HS': '290', 'Avg': '43.43', 'BF': '1490', 'SR': '67.04', '100s': '2', '50s': '3', '0s': '2', '4s': '137', '6s': '5'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316500/316538.png
# Head count 15
# Head count 14
# label-- 222
# result-- 222
# count 171
# https://www.espncricinfo.com/ci/content/player/7502.html
# player- 27 <title>Luke Ronchi profile and biography, stats, records, averages, photos and videos</title>
# ['Luke Ronchi', 'April 23, 1981, Dannevirke, Manawatu, New Zealand', '40y 36d', 'Rock', 'Right hand bat', 'Wicketkeeper', 'Wicketkeeper batter', '1.8 m', [[' Representing two countries ', '1st Most runs in an innings (by batting position) (170*)', '7th Highest career strike rate (114.50)', '8th Highest maiden hundred (170*)', '1st Dismissed for 99 (and 199, 299 etc) (99)', ' 200 runs and 10 wicketkeeping dismissals in a series ', '4th Highest partnership for the tenth wicket (76)', ' Representing two countries ', '8th Most byes conceded in an innings (8)', '1st Most consecutive ducks (3)', ' Representing two countries ']]]
# {'overview': {'Span': '2015-2016', 'Mat': '4', 'Inns': '8', 'NO': '0', 'Runs': '319', 'HS': '88', 'Avg': '39.87', 'BF': '432', 'SR': '73.84', '100s': '0', '50s': '2', '0s': '1', '4s': '41', '6s': '6'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316500/316525.png
# Head count 15
# Head count 14
# label-- 195
# result-- 195
# count 173
# https://www.espncricinfo.com/ci/content/player/506612.html
# player- 28 <title>Matt Henry profile and biography, stats, records, averages, photos and videos</title>
# ['Matthew James Henry', 'December 14, 1991, Christchurch, Canterbury', '29y 166d', 'Right hand bat', 'Right arm fast medium', 'Bowler', [['1st Most consecutive four-wickets-in-an-innings (3)', '7th Fastest to 50 wickets (25)']]]
# {'ICC World Test Champ': {'Span': '2020-2021', 'Mat': '2', 'Inns': '4', 'Overs': '76.0', 'Mdns': '12', 'Runs': '241', 'Wkts': '3', 'BBI': '1/54', 'BBM': '2/148', 'Avg': '80.33', 'Econ': '3.17', 'SR': '152.00', '5w': '0', '10w': '0'}, 'Trans-Tasman Trophy': {'Span': '2015-2020', 'Mat': '3', 'Inns': '6', 'Overs': '127.0', 'Mdns': '23', 'Runs': '440', 'Wkts': '4', 'BBI': '2/105', 'BBM': '2/148', 'Avg': '110.00', 'Econ': '3.46', 'SR': '190.50', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321247.png
# Head count 14
# Head count 15
# label-- 207
# result-- 207
# count 171
# https://www.espncricinfo.com/ci/content/player/226493.html
# player- 29 <title>Hamish Bennett profile and biography, stats, records, averages, photos and videos</title>
# ['Hamish Kyle Bennett', 'February 22, 1987, Timaru', '34y 96d', 'Left hand bat', 'Right arm medium fast', 'Bowler', [[]]]
# {'overview': {'Mat': '1', 'Inns': '1', 'Overs': '15.0', 'Mdns': '2', 'Runs': '47', 'Wkts': '0', 'Econ': '3.13', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321226.png
# Head count 14
# Head count 15
# label-- 187
# result-- 187
# count 171
# https://www.espncricinfo.com/ci/content/player/38924.html
# player- 30 <title>BJ Watling profile and biography, stats, records, averages, photos and videos</title>
# ['Bradley-John Watling', 'July 09, 1985, Durban, South Africa', '35y 324d', 'Right hand bat', 'Wicketkeeper', 'Wicketkeeper batter', [['5th Most dismissals in an innings (6)', '3rd Most catches in a series (42)', '7th Most runs in an innings by a wicketkeeper (205)', ' Hundred and a duck in a match ', ' A hundred and five dismissals in an innings ', '5th Highest partnership for the seventh wicket (261)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '10', 'Inns': '15', 'NO': '1', 'Runs': '417', 'HS': '105*', 'Avg': '29.78', 'BF': '1020', 'SR': '40.88', '100s': '1', '50s': '2', '0s': '1', '4s': '42', '6s': '0'}, 'Trans-Tasman Trophy': {'Span': '2010-2020', 'Mat': '10', 'Inns': '19', 'NO': '0', 'Runs': '422', 'HS': '58', 'Avg': '22.21', 'BF': '1051', 'SR': '40.15', '100s': '0', '50s': '1', '0s': '1', '4s': '50', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319763.png
# Head count 15
# Head count 14
# label-- 220
# result-- 220
# count 171
# https://www.espncricinfo.com/ci/content/player/277914.html
# player- 31 <title>Jeet Raval profile and biography, stats, records, averages, photos and videos</title>
# ['Jeet Ashok Raval', 'September 22, 1988, Gujarat', '32y 249d', 'Left hand bat', 'Legbreak', 'Opening batter', [[]]]
# {'ICC World Test Champ': {'Span': '2019-2020', 'Mat': '4', 'Inns': '7', 'NO': '0', 'Runs': '82', 'HS': '33', 'Avg': '11.71', 'BF': '215', 'SR': '38.13', '100s': '0', '50s': '0', '0s': '1', '4s': '8', '6s': '0'}, 'Trans-Tasman Trophy': {'Span': '2019-2020', 'Mat': '2', 'Inns': '4', 'NO': '0', 'Runs': '45', 'HS': '31', 'Avg': '11.25', 'BF': '103', 'SR': '43.68', '100s': '0', '50s': '0', '0s': '0', '4s': '5', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321231.png
# Head count 15
# Head count 14
# label-- 166
# result-- 166
# count 117
# https://www.espncricinfo.com/ci/content/player/362541.html
# player- 32 <title>Doug Bracewell profile and biography, stats, records, averages, photos and videos</title>
# ['Douglas Andrew John Bracewell', 'September 28, 1990, Tauranga, Bay of Plenty', '30y 243d', 'Right hand bat', 'Right arm fast medium', 'Bowler', [[['JG Bracewell', ' (uncle),'], ['BP Bracewell', ' (father),'], ['MG Bracewell', ' (cousin),'], ['DW Bracewell', ' (uncle),'], ['MA Bracewell', ' (uncle)']]], [[]]]
# {'Trans-Tasman Trophy': {'Span': '2011-2016', 'Mat': '6', 'Inns': '11', 'Overs': '192.1', 'Mdns': '29', 'Runs': '667', 'Wkts': '19', 'BBI': '6/40', 'BBM': '9/60', 'Avg': '35.10', 'Econ': '3.47', 'SR': '60.60', '5w': '1', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321218.png
# Head count 14
# Head count 15
# label-- 207
# result-- 207
# count 171
# https://www.espncricinfo.com/ci/content/player/277911.html
# player- 33 <title>George Worker profile and biography, stats, records, averages, photos and videos</title>
# ['George Herrick Worker', 'August 23, 1989, Palmerston North', '31y 279d', 'Left hand bat', 'Slow left arm orthodox', 'Batting allrounder', [[]]]
# {'overview': {'Span': '2015-2018', 'Mat': '10', 'Inns': '10', 'NO': '2', 'Runs': '272', 'HS': '58', 'Avg': '34.00', 'BF': '379', 'SR': '71.76', '100s': '0', '50s': '3', '0s': '0', '4s': '23', '6s': '3'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_s_100/lsci/db/PICTURES/CMS/303700/303793.png
# Head count 15
# Head count 14
# label-- 193
# result-- 193
# count 144
# https://www.espncricinfo.com/ci/content/player/595783.html
# player- 34 <title>Ajaz Patel profile and biography, stats, records, averages, photos and videos</title>
# ['Ajaz Yunus Patel', 'October 21, 1988, Bombay (now Mumbai), Maharashtra, India', '32y 220d', 'Left hand bat', 'Slow left arm orthodox', 'Bowler', [[]]]
# {'ICC World Test Champ': {'Span': '2019-2020', 'Mat': '3', 'Inns': '6', 'Overs': '92.0', 'Mdns': '15', 'Runs': '267', 'Wkts': '9', 'BBI': '5/89', 'BBM': '6/163', 'Avg': '29.66', 'Econ': '2.90', 'SR': '61.30', '5w': '1', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321200.png
# Head count 14
# Head count 15
# label-- 192
# result-- 192
# count 144
# https://www.espncricinfo.com/ci/content/player/440516.html
# player- 35 <title>Tom Blundell profile and biography, stats, records, averages, photos and videos</title>
# ['Thomas Ackland Blundell', 'September 01, 1990, Wellington', '30y 270d', 'Right hand bat', 'Right arm offbreak', 'Wicketkeeper', 'Wicketkeeper batter', [[' Hundred on debut (107*)']]]
# {'ICC World Test Champ': {'Span': '2019-2021', 'Mat': '8', 'Inns': '13', 'NO': '1', 'Runs': '402', 'HS': '121', 'Avg': '33.50', 'BF': '892', 'SR': '45.06', '100s': '1', '50s': '2', '0s': '0', '4s': '51', '6s': '1'}, 'Trans-Tasman Trophy': {'Span': '2019-2020', 'Mat': '2', 'Inns': '4', 'NO': '0', 'Runs': '172', 'HS': '121', 'Avg': '43.00', 'BF': '344', 'SR': '50.00', '100s': '1', '50s': '0', '0s': '0', '4s': '21', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321315.png
# Head count 15
# Head count 14
# label-- 207
# result-- 207
# count 172
# https://www.espncricinfo.com/ci/content/player/277662.html
# player- 36 <title>Corey Anderson profile and biography, stats, records, averages, photos and videos</title>
# ['Corey James Anderson', 'December 13, 1990, Christchurch, Canterbury', '30y 167d', 'Left hand bat', 'Left arm medium fast', 'Batting allrounder', [['6th Most sixes in an innings (14)', '2nd Best career strike rate (24.7)', '4th Most runs in an innings (by batting position) (94*)', '7th Most sixes in an innings (10)', '1st Most catches in an innings (4)']]]
# {'Trans-Tasman Trophy': {'Span': '2016-2016', 'Mat': '2', 'Inns': '4', 'NO': '0', 'Runs': '150', 'HS': '72', 'Avg': '37.50', 'BF': '323', 'SR': '46.43', '100s': '0', '50s': '1', '0s': '1', '4s': '19', '6s': '4'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316600/316617.png
# Head count 15
# Head count 14
# label-- 221
# result-- 221
# count 171
# https://www.espncricinfo.com/ci/content/player/559066.html
# player- 37 <title>Ish Sodhi profile and biography, stats, records, averages, photos and videos</title>
# ['Inderbir Singh Sodhi', 'October 31, 1992, Ludhiana, India', '28y 210d', 'Right hand bat', 'Legbreak', 'Bowler', [['10th Worst career economy rate (3.75)', '9th Most wickets in career (73)', '10th Most runs conceded in career (1586)', '1st Bowler/batters combinations (4)']]]
# {'overview': {'Span': '2013-2018', 'Mat': '17', 'Inns': '31', 'Overs': '531.0', 'Mdns': '73', 'Runs': '1992', 'Wkts': '41', 'BBI': '4/60', 'BBM': '7/79', 'Avg': '48.58', 'Econ': '3.75', 'SR': '77.70', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/319700/319778.png
# Head count 14
# Head count 15
# label-- 221
# result-- 221
# count 171
# https://www.espncricinfo.com/ci/content/player/226492.html
# player- 38 <title>Martin Guptill profile and biography, stats, records, averages, photos and videos</title>
# ['Martin James Guptill', 'September 30, 1986, Auckland', '34y 241d', 'Right hand bat', 'Right arm offbreak', 'Opening batter', [[' Hundred and a duck in a match ', '6th Highest partnership for the sixth wicket (339)', '2nd Most runs in an innings (by batting position) (237*)', '10th Highest strike rate in an innings (310.00)', ' Hundred on debut (122*)', '6th Most ducks in a series (3)', '2nd Most runs from fours and sixes in an innings (162)', '9th Fastest to 6000 runs (157)', '2nd Most catches in an innings (4)', ' 5000 runs and 50 fielding dismissals ', '4th Most matches in career (102)', '1st Most runs on a single ground (626)', '3rd Fifties in consecutive innings (3)', '3rd Most consecutive innings without a duck (69)', '1st Most sixes in career (147)', '5th Longest individual innings (by balls) (69)', '5th Fastest to 2000 runs (68)', '2nd Most catches in career (58)', '4th Highest partnership for the third wicket (137)', '10th Fifties in consecutive innings (6)', '7th Most sixes in career (351)']]]
# {'Trans-Tasman Trophy': {'Span': '2010-2016', 'Mat': '9', 'Inns': '18', 'NO': '0', 'Runs': '305', 'HS': '58', 'Avg': '16.94', 'BF': '838', 'SR': '36.39', '100s': '0', '50s': '1', '0s': '1', '4s': '36', '6s': '1'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/316500/316591.png
# Head count 15
# Head count 14
# label-- 208
# result-- 208
# count 171
# https://www.espncricinfo.com/ci/content/player/539548.html
# player- 39 <title>Scott Kuggeleijn profile and biography, stats, records, averages, photos and videos</title>
# ['Scott Christopher Kuggeleijn', 'January 03, 1992, Hamilton', '29y 146d', 'Right hand bat', 'Right arm fast medium', 'Bowling allrounder', [[['CM Kuggeleijn', ' (father)']]], [[]]]
# {'overview': {'Mat': '2', 'Inns': '2', 'Overs': '14.0', 'Mdns': '2', 'Runs': '58', 'Wkts': '5', 'BBI': '3/41', 'Avg': '11.60', 'Econ': '4.14', 'SR': '16.80', '4w': '0', '5w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321308.png
# Head count 14
# Head count 15
# label-- 165
# result-- 165
# count 144
# https://www.espncricinfo.com/ci/content/player/547749.html
# player- 40 <title>Will Young profile and biography, stats, records, averages, photos and videos</title>
# ['William Alexander Young', 'November 22, 1992, New Plymouth', '28y 188d', 'Right hand bat', 'Right arm offbreak', 'Top order batter', [[]]]
# {'ICC World Test Champ': {'Mat': '2', 'Inns': '2', 'NO': '0', 'Runs': '48', 'HS': '43', 'Avg': '24.00', 'BF': '98', 'SR': '48.97', '100s': '0', '50s': '0', '0s': '0', '4s': '5', '6s': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321300/321320.png
# Head count 15
# Head count 14
# label-- 191
# result-- 191
# count 171
# https://www.espncricinfo.com/ci/content/player/38141.html
# player- 41 <title>Jeetan Patel profile and biography, stats, records, averages, photos and videos</title>
# ['Jeetan Shashi Patel', 'May 07, 1980, Wellington', '41y 22d', 'Right hand bat', 'Right arm offbreak', 'Bowler', [['10th Most runs in an innings (by batting position) (34)', '3rd Most catches by a substitute in an innings (2)']]]
# {'Trans-Tasman Trophy': {'Span': '2010-2010', 'Mat': '1', 'Inns': '2', 'Overs': '51.0', 'Mdns': '10', 'Runs': '170', 'Wkts': '2', 'BBI': '1/29', 'BBM': '2/170', 'Avg': '85.00', 'Econ': '3.33', 'SR': '153.00', '5w': '0', '10w': '0'}}
# https://img1.hscicdn.com/image/upload/f_auto,t_gn_f_345/lsci/db/PICTURES/CMS/321200/321232.png
# Head count 14
# Head count 15
# label-- 207
# result-- 207
# count 171

# %%
a = final_list_players[0]
df = a.T
for i in range(1,len(final_list_players)):
    lo = final_list_players[i].T
    df = pd.concat([df,lo],axis=1)
final_df = df.T
final_df.to_csv("output_players.csv")
